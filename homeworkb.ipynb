# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmok4081-bit/python/blob/main/homeworkb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# question1

# %%
name = input('enter your name: ')
print(name)
# Out:
# enter your name: sdfa
# sdfa

# %% [markdown]
# question2

# %%
a = 20
b = 15
print(a>b)
# Out:
# True

# %% [markdown]
# question3

# %%
nationality = input('enter your nationality: ')
age = int(input('interyour age: '))
if nationality == 'nigerian' and age >= 18:
  print('you are eligible to vote for cambodia')
else:
  print('not eligibal')

# %% [markdown]
# question 4

# %%
temp = float(input("Enter today temperature: "))

if temp > 35:
    print("Very Hot")
elif temp > 25:
    print("Warm")
elif temp > 15:
    print("Cool")
else:
    print("Cold")

# %% [markdown]
# question 6

# %%
from logging import raiseExceptions
temperature = float(input("Enter today temperature: "))
isitraining = input('is it raining today' )
if temperature > 25.0
  if isitraining == "rain"
     print('stay home')
  else:
    print('go for walk')
else:
  print('nice weather')

# %% [markdown]
# loop through list

# %%
fruits =['apple' , 'banana' , 'coco']
for fruit in fruits:
  print(f'i love {fruit}')
# Out:
# i love apple
# i love banana
# i love coco

# %% [markdown]
# loop through range

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# loop through string

# %%
word = 'python'

for letter in word:
  print(letter)
# Out:
# p
# y
# t
# h
# o
# n

# %% [markdown]
# while

# %%
while True:
    user_answer = input('chlick y toplay click q to quit (y/q)')
    if user_answer == 'y':
      print('playing game')
    elif user_answer == 'q':
      print('quit')
      break
# Out:
# chlick y toplay click q to quit (y/q)q
# quit

# %%
user_input1 = int(input('enter some number: '))
user_input2 = int(input('enter some number: '))

plus = user_input1 + user_input2
print("plus two value together is", plus)
subtraction = user_input1 - user_input2
print("subtraction two value together is", subtraction)
multipication = user_input2 * user_input1
print('The multipication of the tow value is ', multipication)
devision = user_input1 / user_input2
print("the valus of the devisionis", devision)
# Out:
# enter some number: 3
# enter some number: 9
# plus two value together is 12
# subtraction two value together is -6
# The multipication of the tow value is  27
# the valus of the devisionis 0.3333333333333333

# %%
import random
print("hi welcome to the random number game: ")
user_input1 = int(input('input some number :'))
user_input2 = int(input('input some number: '))
random_number = random.randint(user_input1, user_input2)
print('the random is ', random_number)
# Out:
# hi welcome to the random number game:
# input some number :1
# input some number: 10
# the random is  5

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours > 40:
    pay = 40 * rate + (hours - 40) * rate * 1.5
else:
    pay = hours * rate

print(f"Pay: {pay}")
# Out:
# Enter Hours: 5
# Enter Rate: 9
# Pay: 45.0

# %%
3

# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmok4081-bit/python/blob/main/Reviewpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greeting():
  print('Hello')
greeting()
# Out:
# Hello

# %% [markdown]
# passing the in for mantion to function

# %%
def greeting(username):
  print("hello,"+ username.title()+'!')
greeting('sakada')
# Out:
# hello,Sakada!

# %%
def display_function():
  print("Hello I am reviewinf the python")
display_function()
# Out:
# Hello I am reviewinf the python

# %%
def favorite_book(yourfavoitebook):
  print("hello my favorite book is" + yourfavoitebook.title())
favorite_book("power")
# Out:
# hello my favorite book isPower

# %% [markdown]
# passing the argument

# %%
def discribeyoupet(animal_type, pet_name):
  print("/n I have a"+ animal_type)
  print("my"+ animal_type + "name is "+ pet_name.title())
discribeyoupet("dog", 'phovy')
# Out:
# /n I have adog
# mydogname is Phovy

# %%
def gortype(mydogtype, name):
  print("my dog type "+ mydogtype + " very good dog")
gortype('sakada', "phovy")
# Out:
# my dog type sakada very good dog

# %% [markdown]
# keyword argument

# %%
def sakada(animal_type, pet_name):
    print("my pet is a " + animal_type + "his name is " + pet_name)
sakada(animal_type= "cat", pet_name= " ah meac")
# Out:
# my pet is a cathis name is  ah meac

# %%
def discribepet(petname, typeofpet= "dog"):
  print("my pet is a" + petname + "his name is "+ petname )
discribepet(petname = "sakada")
# Out:
# my pet is asakadahis name is sakada

# %%
def make_shirt(size, somewordontheshirt):
  print("my size iz"+ size + "and the coulor "+ somewordontheshirt)
  make_shirt("43", "blue")

# %%
def greeting(first_name, last_name):
  full_name = first_name + last_name
  return full_name.title()
name = greeting("Sakada", 'pun')
print(name)
# Out:
# Sakadapun

# %%
def greet(name):
    print("Hello, " + name + "!")
greet("sakda")
greet("vireak")
# Out:
# Hello, sakda!
# Hello, vireak!

# %%
def add(a, b):
  return a + b
sakada = add(8,9)
print(sakada)
# Out:
# 17

# %% [markdown]
# loop review

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
num = [20,90,79,43]
for n in num:
  print(n)
# Out:
# 20
# 90
# 79
# 43

# %%
person = {"name":"sakada","age":18}
for key, value in person.items():
  print(key, value)
# Out:
# name sakada
# age 18

# %%
for i in range(1,6,2):
  print(i)
# Out:
# 1
# 3
# 5

# %%
for i in range(1,10):
  if i == 7:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(1,10):
  if i == 7:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9

# %%
for i in range(5):
  pass
print(i)
# Out:
# 4
